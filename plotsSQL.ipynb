# %%
import pandas as pd
 
from sqlalchemy import create_engine
from config import user_name,password,port_no,db_name
 
engine = create_engine(f'postgresql://{user_name}:{password}@localhost:{port_no}/{db_name}')
connection = engine.connect()

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import scipy.stats as stats

# %%
query =   """select date,sum(newdeaths) as CovidDeaths, cd.state2 from coviddays cd 
  where cd.state2 = 'NY' and cd.date between '2020-05-01' and '2020-05-15'
 group by cd.date,  cd.state2   """

deaths_df = pd.read_sql(query,connection)
deaths_df.head(20)


deaths_df.to_csv('Exportdataframe.csv')

# %%
query =   """select start_time ,sum(average) as CovidDeaths from accidents_by_day cd 
  where  cd.start_time between '2020-05-01' and '2020-05-15'
 group by cd.start_time,  cd.state2   """

accidents_df = pd.read_sql(query,connection)
accidents_df.head(20)


deaths_df.to_csv('ExportdataAccidents.csv')
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1245                     self.dialect.do_execute(
# -> 1246                         cursor, statement, parameters, context
#    1247                     )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     587     def do_execute(self, cursor, statement, parameters, context=None):
# --> 588         cursor.execute(statement, parameters)
#     589
#
# UndefinedColumn: column cd.date does not exist
# LINE 2:   where  cd.date between '2020-05-01' and '2020-05-15'
#                  ^
#
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
deaths_df.hist(column='newdeaths')
plt.hist(deaths_df['newdeaths'], 20, density=False, label="Covid Deaths")
plt.axvline(deaths_df['date'] , color='k', linestyle='dashed', linewidth=1, label="Covid Deaths")
plt.xlabel("Dates")
plt.ylabel("Covid Deaths")
plt.legend() 
plt.title("Deaths by day")
 #plt.savefig("Deaths by day.png")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-ac51059a5ecc> in <module>
#       1 deaths_df.hist(column='newdeaths')
#       2 plt.hist(deaths_df['newdeaths'], 20, density=False, label="Covid Deaths")
# ----> 3 plt.axvline(deaths_df['date'] , color='k', linestyle='dashed', linewidth=1, label="Covid Deaths")
#       4 plt.xlabel("Dates")
#       5 plt.ylabel("Covid Deaths")
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in axvline(x, ymin, ymax, **kwargs)
#    2423 @docstring.copy(Axes.axvline)
#    2424 def axvline(x=0, ymin=0, ymax=1, **kwargs):
# -> 2425     return gca().axvline(x=x, ymin=ymin, ymax=ymax, **kwargs)
#    2426
#    2427
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in axvline(self, x, ymin, ymax, **kwargs)
#     929         self._process_unit_info(xdata=x, kwargs=kwargs)
#     930         xx = self.convert_xunits(x)
# ...

# %%
#Create a bar chart of average salary by title.

employees_df = pd.read_sql('select * from employees', connection, parse_dates=['birth_date', 'hire_date'])
employees_df.head()


salaries_df = pd.read_sql('select * from salaries', connection)
salaries_df
salaries_df[['salary']] = salaries_df[['salary']].replace( '[\$,)]','', regex=True ).astype(float)

titles_df = pd.read_sql('select * from titles', connection )
titles_df.head()
 

#pd.merge(product,customer,left_on='Product_name',right_on='Purchased_Product')

employees_sal_title = pd.merge(pd.merge(employees_df,titles_df,left_on='emp_title_id',right_on= 'title_id'),salaries_df,on='emp_no')
employees_sal_title.head()
